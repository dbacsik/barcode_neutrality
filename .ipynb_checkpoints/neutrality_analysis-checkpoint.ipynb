# %% [markdown]
# ## Barcode Neutrality Analysis
# This notebook is designed to test whether the specific barcode sequence is having a fitness effect in barcoded virus libraries. Conceptually, a small number of barcodes are represnted in a barcoded virus library many times over. These viruses are passaged a few times, and the proportion of each barcode is assessed at each step of the experiment.
#
# ### Experimental Notes
# These data were generated in the following way:
# - In a single replicate, 20 colonies were picked from a plate of barcoded HA or NA plasmids. These plasmids were grown and purified.
# - In a single replicate, virus was generated containing either bcHA, bcNA, or both bcHA and bcNA segments.
# - These viruses were passaged in technical duplicate.
# - The barcodes were amplified from the viral supernatants and sequenced from the bcHA and/or bcNA segments, as appropriate.

# %% [markdown]
# ### Import Python modules
# Use [dms_tools2](https://jbloomlab.github.io/dms_tools2/) for barcode parsing and [plotnine](https://plotnine.readthedocs.io) for ggplot2-like plotting:

# %%
import glob
import os
import yaml
import pandas as pd
from IPython.display import display, HTML
from plotnine import *
import dms_tools2

# %%
with open('config.yaml') as f:
    config = yaml.load(f)
    
upstream = config['viral_barcode_upstream']
downstream = config['viral_barcode_downstream']
upstream_mismatch = config['viral_barcode_upstream_mismatch']
downstream_mismatch = config['viral_barcode_downstream_mismatch']
barcodelength = config['viral_barcode_length']
fastqfolder = config['fastqfolder']

sample_csv = 'sampledata.csv'
metadata_csv = 'metadata.csv'

results_dir = 'results'
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
samples = pd.read_csv(sample_csv,comment="#").query('datatype == "viral_barcode_fastqs"')

pd.set_option('max.colwidth', -1)
display(HTML(samples.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>datatype</th>
#       <th>gene</th>
#       <th>datafile</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3_Rescue_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>3-Rescue-bcHA-HA_S1_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>5_Rescue_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>5-Rescue-bcHAbcNA-HA_S2_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>6_Passage1_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>6-Passage1-bcHA-HA_S3_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>7_Passage1_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>7-Passage1-bcHA-HA_S4_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>10_Passage1_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>10-Passage1-bcHAbcNA-HA_S5_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>11_Passage1_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>11-Passage1-bcHAbcNA-HA_S6_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>12_Passage2_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>12-Passage2-bcHA-HA_S7_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>13_Passage2_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>13-Passage2-bcHA-HA_S8_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>16_Passage2_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>16-Passage2-bcHAbcNA-HA_S9_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>17_Passage2_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>17-Passage2-bcHAbcNA-HA_S10_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>18_Passage3_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>18-Passage3-bcHA-HA_S11_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>19_Passage3_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>19-Passage3-bcHA-HA_S12_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>22_Passage3_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>22-Passage3-bcHAbcNA-HA_S13_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>23_Passage3_bcHAbcNA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>23-Passage3-bcHAbcNA-HA_S14_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>1_Plasmid_bcHA_HA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>1-Plasmid-bcHA-HA_S15_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>4_Rescue_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>4-Rescue-bcNA-NA_S16_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>5_Rescue_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>5-Rescue-bcHAbcNA-NA_S17_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>8_Passage1_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>8-Passage1-bcNA-NA_S18_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>9_Passage1_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>9-Passage1-bcNA-NA_S19_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>10_Passage1_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>10-Passage1-bcHAbcNA-NA_S20_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>11_Passage1_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>11-Passage1-bcHAbcNA-NA_S21_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>14_Passage2_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>14-Passage2-bcNA-NA_S22_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>15_Passage2_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>15-Passage2-bcNA-NA_S23_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>16_Passage2_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>16-Passage2-bcHAbcNA-NA_S24_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>17_Passage2_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>17-Passage2-bcHAbcNA-NA_S25_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>20_Passage3_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>20-Passage3-bcNA-NA_S26_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>21_Passage3_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>21-Passage3-bcNA-NA_S27_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>22_Passage3_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>22-Passage3-bcHAbcNA-NA_S28_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>23_Passage3_bcHAbcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>23-Passage3-bcHAbcNA-NA_S29_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>2_Plasmid_bcNA_NA</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>2-Plasmid-bcNA-NA_S30_L001_R1_001.fastq.gz</td>
#     </tr>
#   </tbody>
# </table>

# %%
barcodes_file = results_dir + '/' + 'barcodes.csv'
fates_file = results_dir + '/' + 'fates.csv'

if os.path.exists(barcodes_file) and os.path.exists(fates_file):
    barcodes = pd.read_csv(barcodes_file)
    fates = pd.read_csv(fates_file)
else:
    barcodes = []
    fates = []

    for tup in samples.itertuples(index=False):

        parser = dms_tools2.barcodes.IlluminaBarcodeParser(
                    bclen=barcodelength,
                    upstream=upstream[tup.gene],
                    downstream=downstream[tup.gene],
                    upstream_mismatch=upstream_mismatch,
                    downstream_mismatch=downstream_mismatch)

        if '.fastq.gz' in tup.datafile:
            r1files = tup.datafile.split(',')
            r1files = [fastqfolder + s for s in r1files]
        else:
            r1files = glob.glob(os.path.join(tup.datafile, '*R1*.fastq.gz'))

        assert len(r1files)

        print(f"\nReading viral barcodes for {tup.sample} from {len(r1files)} R1 files")
        print("The files are:")
        print(*r1files, sep = "\n")

        ibarcodes, ifates = parser.parse(r1files)

        barcodes.append(ibarcodes.assign(sample=tup.sample))
        fates.append(ifates.assign(sample=tup.sample))

    barcodes = pd.concat(barcodes)
    fates = pd.concat(fates)


    print(f'Writing barcodes to {barcodes_file}')
    barcodes.to_csv(barcodes_file)

    print(f'Writing barcodes to {fates_file}')
    fates.to_csv(fates_file)

# %% [markdown]
# ## Examine "fates" of barcode reads
# We look at how many of the barcode reads we could parse:

# %%
p = (
    4+
    geom_bar(stat='identity', position="stack") +
    ylab('number of reads') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(1 + len(fates['sample'].unique()), 6)) 
    )
_ = p.draw()

# %% [markdown]
# #### Interpretation
# Each sample received ~750k reads. This is extremely deep coverage. The vast majority of barcodes are valid, so this run is of good quality and can be analyzed further.

# %% [markdown]
# ### Load metadata
# Want to load in information about how the experiments were prepared.  I'll load this from the separate metadata file,  calculate a few parameters, and join this onto the sample dataframe.

# %%
metadata = pd.read_csv(metadata_csv,comment="#")

pd.set_option('max.colwidth', -1)
display(HTML(metadata.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample_number</th>
#       <th>sample</th>
#       <th>barcoded_segments</th>
#       <th>step</th>
#       <th>replicate</th>
#       <th>titer</th>
#       <th>gene</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>3_Rescue_bcHA_HA</td>
#       <td>bcHA</td>
#       <td>Rescue</td>
#       <td>None</td>
#       <td>3162.278</td>
#       <td>fluHA</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5_Rescue_bcHAbcNA_HA</td>
#       <td>bcHAbcNA</td>
#       <td>Rescue</td>
#       <td>None</td>
#       <td>6995.642</td>
#       <td>fluHA</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6_Passage1_bcHA_HA</td>
#       <td>bcHA</td>
#       <td>Passage1</td>
#       <td>A</td>
#       <td>31622.777</td>
#       <td>fluHA</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>7_Passage1_bcHA_HA</td>
#       <td>bcHA</td>
#       <td>Passage1</td>
#       <td>B</td>
#       <td>42169.650</td>
#       <td>fluHA</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td
L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>22_Passage3_bcHAbcNA_NA</td>
#       <td>bcHAbcNA</td>
#       <td>Passage3</td>
#       <td>A</td>
#       <td>10000.000</td>

# %% [markdown]
# ## Select real barcodes
# Next, we need to sub-select the real barcodes from the barcodes generated by PCR/sequencing errors. I expect to have a small number of barcodes (~20, based on how many colonies I picked) which are real and have many, many counts. Any other barcodes, with fewer counts, are spurious PCR or sequencing errors.

# %%
barcodes.columns = ['bc_rank','barcode','count','sample']

# %%
#Work with just one sample to speed up analysis development
s1 = samples.loc[samples['sample_number'] == 1]

#Select out barcodes for s1
b1 = barcodes.loc[barcodes['sample'] == s1['sample'].iloc[0]]
b1
# Out:
#        bc_rank           barcode  count             sample
# 9446   0        CGGAATATCATTGAGA  91947  1_Plasmid_bcHA_HA
# 9447   1        CGTACCCGAATTATTC  77432  1_Plasmid_bcHA_HA
# 9448   2        ATACCTCATGCTGAAG  63157  1_Plasmid_bcHA_HA
# 9449   3        ACGTCAGCCCTGTCGG  56046  1_Plasmid_bcHA_HA
# 9450   4        TATTCATTCCTCTTTC  52887  1_Plasmid_bcHA_HA
# 9451   5        TTATTTGTCCCTCGAA  52398  1_Plasmid_bcHA_HA
# 9452   6        ACAGCCGTGTATCCGA  40230  1_Plasmid_bcHA_HA
# 9453   7        CCCCCGAATCCAGCAC  39975  1_Plasmid_bcHA_HA
# 9454   8        TTATGCTGCATAACCG  34386  1_Plasmid_bcHA_HA
# 9455   9        ATGTCGATTGTACTGC  33294  1_Plasmid_bcHA_HA
# 9456   10       CTGGTCATCCTTCACA  27999  1_Plasmid_bcHA_HA
# 9457   11       TTAAAGGCCAAGCATA  23983  1_Plasmid_bcHA_HA
# 9458   12       TGGGTCCAGTGGAGTA  22445  1_Plasmid_bcHA_HA
# 9459   13       GCTGCCATATCGTGTT  21235  1_Plasmid_bcHA_HA
# 9460   14       ATGGGGTCTAATCTCC  19222  1_Plasmid_bcHA_HA
# 9461   15       CTGGAATTCGCTCAAT  17223  1_Plasmid_bcHA_HA
# 9462   16       CACCCATTCTGTGTGT  12471  1_Plasmid_bcHA_HA
# 9463   17       CCAAGACCCATATCCC  9230   1_Plasmid_bcHA_HA
# 9464   18       AATTCGGGTCAGCTTC  8228   1_Plasmid_bcHA_HA
# 9465   19       ACCTCATCAACAATAA  260    1_Plasmid_bcHA_HA
# 9466   20       TGGAATATCATTGAGA  178    1_Plasmid_bcHA_HA
# 9467   21       ATGTCAGCCCTGTCGG  118    1_Plasmid_bcHA_HA
# 9468   22       ATGGTCATCCTTCACA  115    1_Plasmid_bcHA_HA
# 9469   23       TTACCTCATGCTGAAG  108    1_Plasmid_bcHA_HA
# 9470   24       ATGGAATTCGCTCAAT  80     1_Plasmid_bcHA_HA
# 9471   25       ACGTCGATTGTACTGC  65     1_Plasmid_bcHA_HA
# 9472   26       TTGGTCCAGTGGAGTA  59     1_Plasmid_bcHA_HA
# 9473   27       ATATGCTGCATAACCG  56     1_Plasmid_bcHA_HA
# 9474   28       TGTACCCGAATTATTC  54     1_Plasmid_bcHA_HA
# 9475   29       ATAGCCGTGTATCCGA  52     1_Plasmid_bcHA_HA
# ...    ..                    ...  ..                   ...
# 10214  768      TTAAAGGACAAGCATA  1      1_Plasmid_bcHA_HA
# 10215  769      TTAAAGGCCAACCATA  1      1_Plasmid_bcHA_HA
# 10216  770      TTAAAGGCCAAGAATA  1      1_Plasmid_bcHA_HA
# 10217  771      TTAAAGGCCAAGCAAA  1      1_Plasmid_bcHA_HA
# 10218  772      TTAAAGGCCTAGCATA  1      1_Plasmid_bcHA_HA
# 10219  773      TTAAAGGGCAAGCATA  1      1_Plasmid_bcHA_HA
# 10220  774      TTAAAGTCCAATCATA  1      1_Plasmid_bcHA_HA
# 10221  775      TTAAATGCCAAGCATA  1      1_Plasmid_bcHA_HA
# 10222  776      TTAACGGCCAAGCATA  1      1_Plasmid_bcHA_HA
# 10223  777      TTAATGGCCAAGCATA  1      1_Plasmid_bcHA_HA
# 10224  778      TTACAGGCCAAGCATA  1      1_Plasmid_bcHA_HA
# 10225  779      TTACCTCATGCTGAAA  1      1_Plasmid_bcHA_HA
# 10226  780      TTAGCCGTGTATCCGA  1      1_Plasmid_bcHA_HA
# 10227  781      TTAGGCGGCATAACCG  1      1_Plasmid_bcHA_HA
# 10228  782      TTATGCTGCAGAACCG  1      1_Plasmid_bcHA_HA
# 10229  783      TTATGCTGCATAACAG  1      1_Plasmid_bcHA_HA
# 10230  784      TTATGCTGCATAACCC  1      1_Plasmid_bcHA_HA
# 10231  785      TTATGCTGCATAACCT  1      1_Plasmid_bcHA_HA
# 10232  786      TTATGCTGCATAAGCG  1      1_Plasmid_bcHA_HA
# 10233  787      TTATGCTGCATCACCG  1      1_Plasmid_bcHA_HA
# 10234  788      TTATGCTGCCTAACCG  1      1_Plasmid_bcHA_HA
# 10235  789      TTATGCTTCATAACTG  1      1_Plasmid_bcHA_HA
# 10236  790      TTATGGTGCATAACCG  1      1_Plasmid_bcHA_HA
# 10237  791      TTATTCTTCATAACCG  1      1_Plasmid_bcHA_HA
# 10238  792      TTATTGGTCCCTCGAA  1      1_Plasmid_bcHA_HA
# 10239  793      TTATTTGTCCCTCCAA  1      1_Plasmid_bcHA_HA
# 10240  794      TTATTTGTCCCTCGAC  1      1_Plasmid_bcHA_HA
# 10241  795      TTATTTGTCGCTCGAA  1      1_Plasmid_bcHA_HA
# 10242  796      TTGTTTCCAGAAATAC  1      1_Plasmid_bcHA_HA
# 10243  797      TTTGCTCCCTAATGTC  1      1_Plasmid_bcHA_HA
#
# [798 rows x 4 columns]

# %% [markdown]
# ### Plot barcodes by count
# In the barcode dataframe, barcodes are already in descending order of counts. I will plot them to see how the counts are distributed. I expect this to work like a knee plot, where I will see some number of highly-represented barcodes, which fall off to a lot of barcodes with low count numbers.

# %%
p = (
    ggplot(b1, aes('bc_rank','count')) +
    geom_point() +
    scale_y_log10() + scale_x_log10() +
    labs(title=b1['sample'].iloc[0])
)
    
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/scales/scale.py:549: RuntimeWarning: divide by zero encountered in log10
#   return self.trans.transform(x)

# %% [markdown]
# #### Interpretation
# The plot follows the general principles I would expect. There seem to be a bit fewer barcodes than I expected. Plot has a big jump between bc_rank 18 and bc_rank 19. Perhaps a few of the colonies I picked were duplicates.

# %% [markdown]
# ### Call real barcodes
# Next, I will use the knee plot (above) to call real vs spurious barcodes. Essentially, this is at the rank where barcode count falls off dramatically.
